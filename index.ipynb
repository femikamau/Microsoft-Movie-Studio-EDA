# %% [markdown]
# ![Microsoft-Studios-Banner](images/microsoft-studios-banner.png)
#
# # **Microsoft Movie Studio EDA**
#
# ---
#
# ### Author: [Femi Kamau](https://github.com/ctrl-Karugu)

# %% [markdown]
# ## Overview
# (A one-paragraph overview of the project, including the business problem, data, methods, results and recommendations.)

# %% [markdown]
# ## Business Problem
# * Microsoft has decided to enter the original video content scene by creating a new movie studio. However, they don't know anything about creating movies. In order to solve this problem, the analysis shall be centered around answering the following question:
#
#    > ##### What types of films are currently performing the best at the box office?
#
# * According to this [Holywood Reporter](https://www.hollywoodreporter.com/movies/movie-news/what-is-profitable-movie-ever-1269879/) article, we see that the metric used to determine performance of a movie at the box office may vary. Therefore, it is important to clarify that within this analysis, **the metric that shall be used to determine the success of a movie will be based on the return on investment (RoI) of the highest grossing films**. RoI is an important performance measure used by businesses to evaluate the profitability of an investment or compare the efficiency of a number of different investments.
#
# * In order to further understand the types of movies that are currently performing the best at the box office, this analysis will look into the impact following features have on the RoI:
#
#   * Genre
#
#   * Runtime (Length)
#
#   * Director(s) & Writer(s)
#
#   * Gross Revenue
#
#   * Rating
#
#   * Production Budget
#
#   * Release Month

# %% [markdown]
# ## Data Understanding
# * Within this phase analysis, we will be examining datasets obtained from three renowned film database websites: [The Numbers](https://www.the-numbers.com/), [IMDB](https://www.imdb.com/), and [Rotten Tomatoes](https://www.rottentomatoes.com/). The goal is to explore the general structure of the datasets that we are dealing with, as well as to verify the quality of the data itself.

# %% [markdown]
# ##### Load Libraries

# %%
# NumPy for numerical analysis
import numpy as np

# Pandas for data analysis
import pandas as pd

# Matplotlib.pyplot, Seaborn, and Plotly.express for data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Sqlite3 for database management
import sqlite3

# %% [markdown]
# ##### Load Data

# %%
# Function is created to load the data
def load_data(path, data_format):
    
    # if statement used to differentiate data format. Checks if data is in 'csv' format
    if data_format.lower() == 'csv':
        data = pd.read_csv(path, compression='gzip') # 'compression' parameter used since the file is compressed
    
    # elif statement used to check if data is in 'tsv' format  
    elif data_format.lower() == 'tsv':
        data = pd.read_csv(path, compression='gzip', sep='\t', encoding='latin1') # 'sep' parameter used since the file is tab-delimited (tab separated values)
        
    # elif statement used to check if data is in 'db' format
    elif data_format.lower() == 'db':
        conn = sqlite3.connect(path) # returns a Connection object that we will use to interact with the database
        return conn
    # else statement returns an error if the data format is not recognized
    else:
        raise ValueError('Data format not recognized')
    
    return data # returns the DataFrame under the variable name 'data'

# %% [markdown]
# ##### Visualize Missing Data

# %%
# Function is created to identify and visualize the missing data
def missing_values(data):
    
    sns.set_style("whitegrid") # sets the style of the plot

    ax, bar = plt.subplots(figsize=(13, 7)) # creates a figure with a size of 13x7
    
    miss_val = data.isnull().sum().sort_values(ascending = False) # creates a DataFrame that contains the number of missing values for each column
    
    percentages = (data.isnull().sum() / len(data)).sort_values(ascending = False) # creates a DataFrame that contains the percentage of missing values for each column
    
    missing_values_df = pd.DataFrame([miss_val.index, percentages * 100], index=['Columns', 'Percentage (%)']).transpose() # creates a DataFrame that contains the column names and percentage of missing values for each column
    
    missing_values_df = missing_values_df.drop(missing_values_df[missing_values_df['Percentage (%)'] == 0].index) # Drops the columns that have no missing values
    
    sns.barplot(x=missing_values_df['Columns'], y=missing_values_df["Percentage (%)"], palette="Greys_r") # creates a bar plot that shows the percentage of missing values for each column

    # label the axes
    plt.title("Percentage of Missing Data per Movie Feature", fontsize=20)
    plt.xlabel("Movie Features", fontsize=15)
    plt.ylabel("Percentage (%)", fontsize=15)
    plt.xticks(rotation=45) # rotates the x-axis labels
    
    return plt.show() # returns the bar plot

# %% [markdown]
# ##### Dataset 1: Rotten Tomatoes - Movie Information

# %%
# Load the movie information as a pandas DataFrame and assign it to the variable 'movie_info_df'
movie_info_df = load_data('data/rt.movie_info.tsv.gz', 'tsv')

# Preview the first few rows of the DataFrame
movie_info_df.head()
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# ...

# %%
# General description of the movie_info_df data
movie_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1560 entries, 0 to 1559
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1560 non-null   int64
#  1   synopsis      1498 non-null   object
#  2   rating        1557 non-null   object
#  3   genre         1552 non-null   object
#  4   director      1361 non-null   object
#  5   writer        1111 non-null   object
#  6   theater_date  1201 non-null   object
#  7   dvd_date      1201 non-null   object
#  8   currency      340 non-null    object
#  9   box_office    340 non-null    object
#  10  runtime       1530 non-null   object
#  11  studio        494 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 146.4+ KB

# %%
# Graphical representation of the missing values in the DataFrame
missing_values(movie_info_df)

# %% [markdown]
# ##### Dataset 2: Rotten Tomatoes - Reviews

# %%
# Load the movie reviews as a pandas DataFrame and assign it to the variable 'movie_reviews_df'
movie_reviews_df = load_data('data/rt.reviews.tsv.gz', 'tsv') 

# Preview the first few rows of the DataFrame
movie_reviews_df.head()
# Out:
#    id                                             review rating   fresh  \
# 0   3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1   3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2   3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3   3  Continuing along a line introduced in last yea...    NaN   fresh
# 4   3             ... a perverse twist on neorealism...     NaN   fresh
#
#            critic  top_critic         publisher               date
# 0      PJ Nabarro           0   Patrick Nabarro  November 10, 2018
# 1  Annalee Newitz           0           io9.com       May 23, 2018
# 2    Sean Axmaker           0  Stream on Demand    January 4, 2018
# 3   Daniel Kasman           0              MUBI  November 16, 2017
# 4             NaN           0      Cinema Scope   October 12, 2017

# %%
# General description of the 'movie_reviews_df' data
movie_reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54432 entries, 0 to 54431
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          54432 non-null  int64
#  1   review      48869 non-null  object
#  2   rating      40915 non-null  object
#  3   fresh       54432 non-null  object
#  4   critic      51710 non-null  object
#  5   top_critic  54432 non-null  int64
#  6   publisher   54123 non-null  object
#  7   date        54432 non-null  object
# dtypes: int64(2), object(6)
# memory usage: 3.3+ MB

# %%
# Visualize the missing values in the 'movie_reviews_df' DataFrame
missing_values(movie_reviews_df)

# %% [markdown]
# ##### Dataset 3: The Numbers - Movie Budgets

# %%
# Load the movie budgets as a pandas DataFrame and assign it to the variable 'movie_budgets_df'
movie_budgets_df = load_data('data/tn.movie_budgets.csv.gz', 'csv')

# Preview the first few rows of the 'movie_budgets_df' DataFrame
movie_budgets_df.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
# General description of the 'movie_budgets_df' data
movie_budgets_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %% [markdown]
# (Analysis of the dataset obtained from [The Numbers](https://www.the-numbers.com/))

# %% [markdown]
# ##### Dataset 4: IMDB
# * The ERD of the IMDB dataset is shown below:
#
# ![IMDB Data ERD](images/imdb_data_erd.jpeg)

# %%
# Load the imdb data into a DataFrame which returns a Connection object
conn = load_data('data/im.db/im.db', 'db')

# View the tables within the idmb database as a DataFrame
imdb_tables = pd.read_sql("""SELECT name FROM sqlite_master WHERE type = 'table';""", conn)
imdb_tables
# Out:
#             name
# 0   movie_basics
# 1      directors
# 2      known_for
# 3     movie_akas
# 4  movie_ratings
# 5        persons
# 6     principals
# 7        writers

# %% [markdown]
# ##### Examination of `movie_basics` table

# %%
# Preview the tables of interest in the IMDB data
movie_basics_df = pd.read_sql("""
                      SELECT * 
                        FROM  movie_basics AS mb """, conn)

movie_basics_df.head()
# Out:
#     movie_id                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
movie_basics_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   movie_id         146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
missing_values(movie_basics_df)

# %% [markdown]
# ##### Examination of `persons` table

# %%
# Preview the tables of interest in the IMDB data
persons_df = pd.read_sql("""
                      SELECT * 
                        FROM  persons
                      ;
                      """, conn)

persons_df.head()
# Out:
#    person_id       primary_name  birth_year  death_year  \
# 0  nm0061671  Mary Ellen Bauder         NaN         NaN
# 1  nm0061865       Joseph Bauer         NaN         NaN
# 2  nm0062070         Bruce Baum         NaN         NaN
# 3  nm0062195       Axel Baumann         NaN         NaN
# 4  nm0062798        Pete Baxter         NaN         NaN
#
#                                  primary_profession
# 0         miscellaneous,production_manager,producer
# 1        composer,music_department,sound_department
# 2                        miscellaneous,actor,writer
# 3  camera_department,cinematographer,art_department
# 4  production_designer,art_department,set_decorator

# %%
persons_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 606648 entries, 0 to 606647
# Data columns (total 5 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   person_id           606648 non-null  object
#  1   primary_name        606648 non-null  object
#  2   birth_year          82736 non-null   float64
#  3   death_year          6783 non-null    float64
#  4   primary_profession  555308 non-null  object
# dtypes: float64(2), object(3)
# memory usage: 23.1+ MB

# %%
missing_values(persons_df)

# %% [markdown]
# ##### Examination of `movie_ratings` table

# %%
# Preview the tables of interest in the IMDB data
movie_ratings_df = pd.read_sql("""
                      SELECT * 
                        FROM  movie_ratings
                      ;
                      """, conn)

movie_ratings_df.head()
# Out:
#      movie_id  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
movie_ratings_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   movie_id       73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %% [markdown]
# ##### Examination of `movie_akas` table

# %%
movie_akas_df = pd.read_sql("""
                      SELECT * 
                        FROM  movie_akas
                      ;
                      """, conn)

movie_akas_df.head()
# Out:
#     movie_id  ordering                                    title region  \
# 0  tt0369610        10                            Джурасик свят     BG
# 1  tt0369610        11                        Jurashikku warudo     JP
# 2  tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3  tt0369610        13                  O Mundo dos Dinossauros     BR
# 4  tt0369610        14                           Jurassic World     FR
#
#   language        types   attributes  is_original_title
# 0       bg         None         None                0.0
# 1     None  imdbDisplay         None                0.0
# 2     None  imdbDisplay         None                0.0
# 3     None         None  short title                0.0
# 4     None  imdbDisplay         None                0.0

# %%
movie_akas_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 331703 entries, 0 to 331702
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   movie_id           331703 non-null  object
#  1   ordering           331703 non-null  int64
#  2   title              331703 non-null  object
#  3   region             278410 non-null  object
#  4   language           41715 non-null   object
#  5   types              168447 non-null  object
#  6   attributes         14925 non-null   object
#  7   is_original_title  331678 non-null  float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 20.2+ MB

# %%
missing_values(movie_akas_df)

# %% [markdown]
# ##### Read `directors` table into dataframe

# %%
directors_df = pd.read_sql("""
                      SELECT DISTINCT * 
                        FROM  directors
                      ;
                      """, conn)

# %% [markdown]
# ##### Read `writers` table into dataframe

# %%
writers_df = pd.read_sql("""
                      SELECT * 
                        FROM  writers
                      ;
                      """, conn)

# %% [markdown]
# ##### Read `known_for` table into dataframe

# %%
known_for_df = pd.read_sql("""
                      SELECT * 
                        FROM  known_for
                      ;
                      """, conn)

# %% [markdown]
# ## Data Preparation
# > The data preparation phase uses the insights derived from the data understanding stage and will be used to prepare the data for analysis.
#
# * Based on the metric of success we are using used to determine the best performing films in the box office, we first need to identify and clean the relevant data that shall be used to calculate the RoI. Furthermore, the business problem is looking for the types of films that are **currently** performing the best, therefore, we will narrow our analysis to the films that have been released within the past 10 years.
#
# We will be obtaining the RoI information from the 'movie_budgets_df' DataFrame:

# %%
# Limit the analysis to films that have been released within the past 10 years
movie_budgets_df = movie_budgets_df[movie_budgets_df['release_date'].apply(lambda x: int(x.split(" ")[-1]) >= 2012)]

movie_budgets_df # Preview the updated 'movie_budgets_df' DataFrame
# Out:
#       id  release_date                                 movie  \
# 2      3   Jun 7, 2019                          Dark Phoenix
# 3      4   May 1, 2015               Avengers: Age of Ultron
# 4      5  Dec 15, 2017     Star Wars Ep. VIII: The Last Jedi
# 5      6  Dec 18, 2015  Star Wars Ep. VII: The Force Awakens
# 6      7  Apr 27, 2018                Avengers: Infinity War
# ...   ..           ...                                   ...
# 5761  62  Dec 31, 2014                  Stories of Our Lives
# 5771  72  May 19, 2015                      Family Motocross
# 5772  73  Jan 13, 2012                             Newlyweds
# 5777  78  Dec 31, 2018                                Red 11
# 5780  81  Sep 29, 2015                  A Plague So Pleasant
#
#      production_budget domestic_gross worldwide_gross
# 2         $350,000,000    $42,762,350    $149,762,350
# 3         $330,600,000   $459,005,868  $1,403,013,963
# 4         $317,000,000   $620,181,382  $1,316,721,747
# ...

# %% [markdown]
# Next, we need to obtain the Top 200 highest grossing films

# %%
# Define a function to convert the production_budget, domestic_gross, and worldwide_gross columns to numeric values
def convert_to_numeric(df, column):
    df[column] = pd.to_numeric(df[column].str.replace(",", "").str.replace("$", ""))
    
    return df

convert_to_numeric(movie_budgets_df, 'production_budget') # convert the production_budget column to numeric values
convert_to_numeric(movie_budgets_df, 'domestic_gross') # convert the domestic_gross column to numeric values
convert_to_numeric(movie_budgets_df, 'worldwide_gross') # convert the worldwide_gross column to numeric values

movie_budgets_df # Preview the updated 'movie_budgets_df' DataFrame
# Out:
#       id  release_date                                 movie  \
# 2      3   Jun 7, 2019                          Dark Phoenix
# 3      4   May 1, 2015               Avengers: Age of Ultron
# 4      5  Dec 15, 2017     Star Wars Ep. VIII: The Last Jedi
# 5      6  Dec 18, 2015  Star Wars Ep. VII: The Force Awakens
# 6      7  Apr 27, 2018                Avengers: Infinity War
# ...   ..           ...                                   ...
# 5761  62  Dec 31, 2014                  Stories of Our Lives
# 5771  72  May 19, 2015                      Family Motocross
# 5772  73  Jan 13, 2012                             Newlyweds
# 5777  78  Dec 31, 2018                                Red 11
# 5780  81  Sep 29, 2015                  A Plague So Pleasant
#
#       production_budget  domestic_gross  worldwide_gross
# 2             350000000        42762350        149762350
# 3             330600000       459005868       1403013963
# 4             317000000       620181382       1316721747
# ...

# %%
# Find the Top 200 films with the worldwide gross
movie_budgets_df = movie_budgets_df.sort_values(by='worldwide_gross', ascending=False)[:200]
movie_budgets_df # Preview the updated 'movie_budgets_df' DataFrame
# Out:
#      id  release_date                                          movie  \
# 5     6  Dec 18, 2015           Star Wars Ep. VII: The Force Awakens
# 6     7  Apr 27, 2018                         Avengers: Infinity War
# 33   34  Jun 12, 2015                                 Jurassic World
# 66   67   Apr 3, 2015                                      Furious 7
# 26   27   May 4, 2012                                   The Avengers
# ..   ..           ...                                            ...
# 327  28  Dec 21, 2016                                     Passengers
# 124  25  May 31, 2019                 Godzilla: King of the Monsters
# 698  99   Jun 8, 2018                                    Oceanâs 8
# 329  30  Sep 30, 2016  Miss Peregrineâs Home for Peculiar Children
# 321  22  Mar 20, 2015                The Divergent Series: Insurgent
#
#      production_budget  domestic_gross  worldwide_gross
# 5            306000000       936662225       2053311220
# ...

# %%
# Create a new column called 'RoI' that calculates the return on investment (RoI) for each film
# The formula for calculating RoI is to divide the film’s box office earnings by the production budget and multiplying the result by 100
movie_budgets_df['RoI'] = movie_budgets_df['worldwide_gross'] / movie_budgets_df['production_budget'] * 100

movie_budgets_df # Preview the updated 'movie_budgets_df' DataFrame
# Out:
#      id  release_date                                          movie  \
# 5     6  Dec 18, 2015           Star Wars Ep. VII: The Force Awakens
# 6     7  Apr 27, 2018                         Avengers: Infinity War
# 33   34  Jun 12, 2015                                 Jurassic World
# 66   67   Apr 3, 2015                                      Furious 7
# 26   27   May 4, 2012                                   The Avengers
# ..   ..           ...                                            ...
# 327  28  Dec 21, 2016                                     Passengers
# 124  25  May 31, 2019                 Godzilla: King of the Monsters
# 698  99   Jun 8, 2018                                    Oceanâs 8
# 329  30  Sep 30, 2016  Miss Peregrineâs Home for Peculiar Children
# 321  22  Mar 20, 2015                The Divergent Series: Insurgent
#
#      production_budget  domestic_gross  worldwide_gross         RoI
# 5            306000000       936662225       2053311220  671.016739
# ...

# %%
# Sort the DataFrame according to the 'RoI' column
movie_budgets_df = movie_budgets_df.sort_values(by='RoI', ascending=False)

movie_budgets_df # Preview the updated 'movie_budgets_df' DataFrame
# Out:
#       id  release_date                           movie  production_budget  \
# 3517  18  May 25, 2012                Les Intouchables           10800000
# 3342  43   Jun 6, 2014          The Fault in Our Stars           12000000
# 2491  92   Dec 9, 2016                      La La Land           20000000
# 3001   2  Aug 11, 2017             Annabelle: Creation           15000000
# 1623  24   Sep 8, 2017                              It           35000000
# ...   ..           ...                             ...                ...
# 78    79  Jul 22, 2016                Star Trek Beyond          185000000
# 72    73  Nov 25, 2015               The Good Dinosaur          187500000
# 124   25  May 31, 2019  Godzilla: King of the Monsters          170000000
# 11    12  May 25, 2018         Solo: A Star Wars Story          275000000
# 31    32  May 18, 2012                      Battleship          220000000
#
#       domestic_gross  worldwide_gross          RoI
# ...

# %% [markdown]
# Now that we have identified and cleaned the data that is being used to get films that are performing the best accodring to our metric, we need to understand what makes them successful. For this stage of data preparation, we shall be looking to integrate the key features of the top performing films into one dataset if possible. These features include Genre, Runtime (Length), Director(s) & Writer(s), Cast, Gross Revenue, Rating, and  Production Budget.

# %%
# Identify a unique column within the 'movie_budgets_df' DataFrame that can be used to integrate data from other sources.
print(f"The release_date column has {len(movie_budgets_df.release_date.unique())} unique values") # identify number the unique release_date values
print(f"The movie column has {len(movie_budgets_df.movie.unique())} unique values") # identify number of unique movie names
# Out:
# The release_date column has 178 unique values
# The movie column has 200 unique values

# %% [markdown]
# Since this dataset if from a different source than the rest, using the 'id' column to join the other datasets would not be a good decision. Therefore, we will be using the 'movie' column to join other values since it is a unique identifier within this dataset and will most probably also appear in the other datasets.
# The first DataFrame that we shall be looking join to the 'movie_data_df' DataFrame will be the 'movie_basics_df'.

# %%
# We shall be using either the original_title/primary_title column to join the two DataFrames

# Try joining the 'movie_budgets_df' and 'movie_titles_df' DataFrames on the 'original_title' column first
option_1 = movie_budgets_df.join(movie_basics_df.set_index('original_title'), on='movie', how='inner')
print(option_1.info())

# Try joining the 'movie_budgets_df' and 'movie_titles_df' DataFrames on the 'primary_title' column
option_2 = movie_budgets_df.join(movie_basics_df.set_index('primary_title'), on='movie', how='inner')
print(option_2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 222 entries, 3342 to 31
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 222 non-null    int64
#  1   release_date       222 non-null    object
#  2   movie              222 non-null    object
#  3   production_budget  222 non-null    int64
#  4   domestic_gross     222 non-null    int64
#  5   worldwide_gross    222 non-null    int64
#  6   RoI                222 non-null    float64
#  7   movie_id           222 non-null    object
#  8   primary_title      222 non-null    object
#  9   start_year         222 non-null    int64
#  10  runtime_minutes    211 non-null    float64
#  11  genres             219 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 22.5+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 235 entries, 3342 to 31
# Data columns (total 12 columns):
# ...

# %% [markdown]
# There seems to a one-to-many relationship in both options hence why we have more than 200 films returned in the joined DataFrame. This is understandable as it is possible for movies to share names. In order to fix this problem, we will first begin by dropping the movies in the 'movie_basics_df' DataFrame that are older than 10 years. This will reduce the chances of having a movie that shares the same name with another movie.

# %%
# Drop the films in the 'movie_basics_df' that are older than 10 years
movie_basics_df = movie_basics_df[movie_basics_df['start_year'] >= 2012]

movie_basics_df # Preview the updated 'movie_basics_df' DataFrame
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %% [markdown]
# Now we check to see if that has reduced out one-to-many relationships.

# %%
option_1 = movie_budgets_df.join(movie_basics_df.set_index('original_title'), on='movie', how='inner')
print(option_1.info())

option_2 = movie_budgets_df.join(movie_basics_df.set_index('primary_title'), on='movie', how='inner')
print(option_2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 213 entries, 3342 to 31
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 213 non-null    int64
#  1   release_date       213 non-null    object
#  2   movie              213 non-null    object
#  3   production_budget  213 non-null    int64
#  4   domestic_gross     213 non-null    int64
#  5   worldwide_gross    213 non-null    int64
#  6   RoI                213 non-null    float64
#  7   movie_id           213 non-null    object
#  8   primary_title      213 non-null    object
#  9   start_year         213 non-null    int64
#  10  runtime_minutes    204 non-null    float64
#  11  genres             211 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 21.6+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 221 entries, 3342 to 31
# Data columns (total 12 columns):
# ...

# %% [markdown]
# We see that this has slighly reduced the one-to-many relationships. However, there is still some more cleaning to be done. Based on the two join options, we will be looking to join using the 'original_title' column. The missing values in the 'runtime_minutes' column will make task of narrowing the data down to the Top 200 films faster, and there are fewer duplicate records to deal with.

# %%
# Join the 'movie_budgets_df' and 'movie_titles_df' DataFrames on the 'original_title' column and assign the resulting DataFrame to 'top_movies_df'
top_movies_df = movie_budgets_df.join(movie_basics_df.set_index('original_title'), on='movie', how='inner')

top_movies_df # Preview the updated 'top_movies_df' DataFrame
# Out:
#       id  release_date                           movie  production_budget  \
# 3342  43   Jun 6, 2014          The Fault in Our Stars           12000000
# 2491  92   Dec 9, 2016                      La La Land           20000000
# 3001   2  Aug 11, 2017             Annabelle: Creation           15000000
# 1623  24   Sep 8, 2017                              It           35000000
# 2865  66   Apr 6, 2018                   A Quiet Place           17000000
# ...   ..           ...                             ...                ...
# 78    79  Jul 22, 2016                Star Trek Beyond          185000000
# 72    73  Nov 25, 2015               The Good Dinosaur          187500000
# 124   25  May 31, 2019  Godzilla: King of the Monsters          170000000
# 11    12  May 25, 2018         Solo: A Star Wars Story          275000000
# 31    32  May 18, 2012                      Battleship          220000000
#
#       domestic_gross  worldwide_gross          RoI   movie_id  \
# ...

# %%
# Drop records that are missing 'runtime_minutes' values
top_movies_df = top_movies_df.dropna(subset=['runtime_minutes'])

top_movies_df # Preview the updated 'top_movies_df' DataFrame
# Out:
#       id  release_date                           movie  production_budget  \
# 3342  43   Jun 6, 2014          The Fault in Our Stars           12000000
# 2491  92   Dec 9, 2016                      La La Land           20000000
# 3001   2  Aug 11, 2017             Annabelle: Creation           15000000
# 1623  24   Sep 8, 2017                              It           35000000
# 2865  66   Apr 6, 2018                   A Quiet Place           17000000
# ...   ..           ...                             ...                ...
# 78    79  Jul 22, 2016                Star Trek Beyond          185000000
# 72    73  Nov 25, 2015               The Good Dinosaur          187500000
# 124   25  May 31, 2019  Godzilla: King of the Monsters          170000000
# 11    12  May 25, 2018         Solo: A Star Wars Story          275000000
# 31    32  May 18, 2012                      Battleship          220000000
#
#       domestic_gross  worldwide_gross          RoI   movie_id  \
# ...

# %% [markdown]
# The DataFrame has now been narrowed down to 204 records. In order to drop the illegitimate duplicate records, we will compare the year value in the 'release_date' column against the 'start_year' column. Records that return conflicting values will be dropped.

# %%
# Create a new column called 'release_year' that extracts the year from the 'release_date' column
top_movies_df['release_year'] = top_movies_df['release_date'].apply(lambda x: int(x.split(" ")[-1]))


#Compare the 'release_year' column to the 'start_year' column. Drop the conflicting records
top_movies_df = top_movies_df.loc[top_movies_df['release_year'] == top_movies_df['start_year']]

top_movies_df # Preview the updated 'top_movies_df' DataFrame
# Out:
# <ipython-input-38-21391e8ecdab>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_movies_df['release_year'] = top_movies_df['release_date'].apply(lambda x: int(x.split(" ")[-1]))
#       id  release_date                           movie  production_budget  \
# 3342  43   Jun 6, 2014          The Fault in Our Stars           12000000
# 2491  92   Dec 9, 2016                      La La Land           20000000
# 3001   2  Aug 11, 2017             Annabelle: Creation           15000000
# 1623  24   Sep 8, 2017                              It           35000000
# 2865  66   Apr 6, 2018                   A Quiet Place           17000000
# ...   ..           ...                             ...                ...
# ...

# %%
len(top_movies_df['movie'].unique()) # Identify the number of movie titles in the 'top_movies_df' DataFrame
# Out:
# 170

# %% [markdown]
# The length of the DataFrame has been significantly reduced. This means that we have possibly gotten rid of invalid records. With the DataFrame down to 174 records and the number of unique movie titles now at 170, this means that there could be up to 4 duplicate records that need to be checked.

# %%
# Identify the titles of the duplicate movie titles
duplicate_movie_titles = top_movies_df[top_movies_df.duplicated(subset='movie')].movie.unique()
print(f"{len(duplicate_movie_titles)} duplicate title(s)") # identify number of duplicate movie titles

# Identify the movie ids of the unique movie titles
duplicate_movie_ids = top_movies_df[top_movies_df.duplicated(subset='movie_id')].movie_id.unique()
print(f"{len(duplicate_movie_ids)} duplicate id(s)") # identify number of duplicate movie ids
# Out:
# 3 duplicate title(s)
# 0 duplicate id(s)

# %%
# Examine the records that belong to the specified set of movies
top_movies_df[top_movies_df.movie.isin(duplicate_movie_titles)]
# Out:
#      id  release_date       movie  production_budget  domestic_gross  \
# 412  13  Mar 13, 2015  Cinderella           95000000       201151353
# 412  13  Mar 13, 2015  Cinderella           95000000       201151353
# 101   2  Nov 22, 2017        Coco          175000000       209726015
# 101   2  Nov 22, 2017        Coco          175000000       209726015
# 243  44  Mar 27, 2015        Home          130000000       177397510
# 243  44  Mar 27, 2015        Home          130000000       177397510
# 243  44  Mar 27, 2015        Home          130000000       177397510
#
#      worldwide_gross         RoI   movie_id primary_title  start_year  \
# 412        534551353  562.685635  tt1661199    Cinderella        2015
# 412        534551353  562.685635  tt5089556    Cinderella        2015
# 101        798008101  456.004629  tt2380307          Coco        2017
# 101        798008101  456.004629  tt7002100          Coco        2017
# ...

# %% [markdown]
# We have identified the records that are duplicated. Before we can decide which records to drop, we will need to integrate more features into our top_movies_df DataFrame.

# %%
# Join the 'movie_ratings_df' to the 'top_movies_df' DataFrame on the 'movie_id' column
top_movies_df = top_movies_df.join(movie_ratings_df.set_index('movie_id'), on='movie_id', how='inner')

top_movies_df # Preview the updated 'top_movies_df' DataFrame
# Out:
#       id  release_date                           movie  production_budget  \
# 3342  43   Jun 6, 2014          The Fault in Our Stars           12000000
# 2491  92   Dec 9, 2016                      La La Land           20000000
# 3001   2  Aug 11, 2017             Annabelle: Creation           15000000
# 1623  24   Sep 8, 2017                              It           35000000
# 2865  66   Apr 6, 2018                   A Quiet Place           17000000
# ...   ..           ...                             ...                ...
# 78    79  Jul 22, 2016                Star Trek Beyond          185000000
# 72    73  Nov 25, 2015               The Good Dinosaur          187500000
# 124   25  May 31, 2019  Godzilla: King of the Monsters          170000000
# 11    12  May 25, 2018         Solo: A Star Wars Story          275000000
# 31    32  May 18, 2012                      Battleship          220000000
#
#       domestic_gross  worldwide_gross          RoI   movie_id  \
# ...

# %% [markdown]
# Now we check whether we still have dupplicate records.

# %%
# Identify the titles of the duplicate movie titles
duplicate_movie_titles = set(top_movies_df[top_movies_df.duplicated(subset='movie')].movie)
print(f"{len(duplicate_movie_titles)} duplicate movie title(s)") # identify number of duplicate movie titles
# Out:
# 1 duplicate movie title(s)

# %%
# Examine the records that belong to the specified set of movies
top_movies_df[top_movies_df.movie.isin(duplicate_movie_titles)]
# Out:
#      id  release_date movie  production_budget  domestic_gross  \
# 101   2  Nov 22, 2017  Coco          175000000       209726015
# 101   2  Nov 22, 2017  Coco          175000000       209726015
#
#      worldwide_gross         RoI   movie_id primary_title  start_year  \
# 101        798008101  456.004629  tt2380307          Coco        2017
# 101        798008101  456.004629  tt7002100          Coco        2017
#
#      runtime_minutes                      genres  release_year  averagerating  \
# 101            105.0  Adventure,Animation,Comedy          2017            8.4
# 101             98.0                      Horror          2017            7.4
#
#      numvotes
# 101    277194
# 101        35

# %% [markdown]
# Since there is no definate way of justifying which data is correct between both records, it is best to drop them both than risk having incorrect data.

# %%
# Drop records that have 'Coco' as the movie title
top_movies_df.drop(top_movies_df[top_movies_df['movie'] == 'Coco'].index, inplace = True)

top_movies_df # Preview the updated 'top_movies_df' DataFrame
# Out:
#       id  release_date                           movie  production_budget  \
# 3342  43   Jun 6, 2014          The Fault in Our Stars           12000000
# 2491  92   Dec 9, 2016                      La La Land           20000000
# 3001   2  Aug 11, 2017             Annabelle: Creation           15000000
# 1623  24   Sep 8, 2017                              It           35000000
# 2865  66   Apr 6, 2018                   A Quiet Place           17000000
# ...   ..           ...                             ...                ...
# 78    79  Jul 22, 2016                Star Trek Beyond          185000000
# 72    73  Nov 25, 2015               The Good Dinosaur          187500000
# 124   25  May 31, 2019  Godzilla: King of the Monsters          170000000
# 11    12  May 25, 2018         Solo: A Star Wars Story          275000000
# 31    32  May 18, 2012                      Battleship          220000000
#
#       domestic_gross  worldwide_gross          RoI   movie_id  \
# ...

# %% [markdown]
# Now that we no longer have duplicate data, we can start cleaning the DataFrame by dropping the irrelevant columns and organizing the DataFrame. The columns that shall be dropped are: `'id'`, `'domestic_gross'`, `'primary_title'`, `'start_year'`, `'release_year'`, and `'numvotes'`

# %%
# Drop the 'id', 'domestic_gross', 'primary_title', 'start_year', 'release_year', and 'numvotes' column from the 'top_movies_df' DataFrame
top_movies_df.drop(columns=['id', 'domestic_gross', 'primary_title', 'start_year', 'release_year', 'numvotes'], inplace=True)

top_movies_df # Preview the updated 'top_movies_df' DataFrame
# Out:
#       release_date                           movie  production_budget  \
# 3342   Jun 6, 2014          The Fault in Our Stars           12000000
# 2491   Dec 9, 2016                      La La Land           20000000
# 3001  Aug 11, 2017             Annabelle: Creation           15000000
# 1623   Sep 8, 2017                              It           35000000
# 2865   Apr 6, 2018                   A Quiet Place           17000000
# ...            ...                             ...                ...
# 78    Jul 22, 2016                Star Trek Beyond          185000000
# 72    Nov 25, 2015               The Good Dinosaur          187500000
# 124   May 31, 2019  Godzilla: King of the Monsters          170000000
# 11    May 25, 2018         Solo: A Star Wars Story          275000000
# 31    May 18, 2012                      Battleship          220000000
#
#       worldwide_gross          RoI   movie_id  runtime_minutes  \
# ...

# %%
# Reset the index of the 'top_movies_df' DataFrame
top_movies_df.set_index('movie_id', inplace=True)
top_movies_df.reset_index(inplace=True)
top_movies_df
# Out:
#       movie_id  release_date                           movie  \
# 0    tt2582846   Jun 6, 2014          The Fault in Our Stars
# 1    tt3783958   Dec 9, 2016                      La La Land
# 2    tt5140878  Aug 11, 2017             Annabelle: Creation
# 3    tt1396484   Sep 8, 2017                              It
# 4    tt6644200   Apr 6, 2018                   A Quiet Place
# ..         ...           ...                             ...
# 164  tt2660888  Jul 22, 2016                Star Trek Beyond
# 165  tt1979388  Nov 25, 2015               The Good Dinosaur
# 166  tt3741700  May 31, 2019  Godzilla: King of the Monsters
# 167  tt3778644  May 25, 2018         Solo: A Star Wars Story
# 168  tt1440129  May 18, 2012                      Battleship
#
#      production_budget  worldwide_gross          RoI  runtime_minutes  \
# 0             12000000        307166834  2559.723617            126.0
# 1             20000000        426351163  2131.755815            128.0
# ...

# %%
# Convert the 'release_date' column to a datetime object
top_movies_df['release_date'] = pd.to_datetime(top_movies_df['release_date'], format='%b %d, %Y')

# %%
top_movies_df
# Out:
#       movie_id release_date                           movie  \
# 0    tt2582846   2014-06-06          The Fault in Our Stars
# 1    tt3783958   2016-12-09                      La La Land
# 2    tt5140878   2017-08-11             Annabelle: Creation
# 3    tt1396484   2017-09-08                              It
# 4    tt6644200   2018-04-06                   A Quiet Place
# ..         ...          ...                             ...
# 164  tt2660888   2016-07-22                Star Trek Beyond
# 165  tt1979388   2015-11-25               The Good Dinosaur
# 166  tt3741700   2019-05-31  Godzilla: King of the Monsters
# 167  tt3778644   2018-05-25         Solo: A Star Wars Story
# 168  tt1440129   2012-05-18                      Battleship
#
#      production_budget  worldwide_gross          RoI  runtime_minutes  \
# 0             12000000        307166834  2559.723617            126.0
# 1             20000000        426351163  2131.755815            128.0
# ...

# %%
# General overview of the numeric data in the 'top_movies_df' DataFrame
top_movies_df.describe()
# Out:
#        production_budget  worldwide_gross          RoI  runtime_minutes  \
# count       1.690000e+02     1.690000e+02   169.000000       169.000000
# mean        1.402728e+08     6.186634e+08   555.407647       119.224852
# std         6.460577e+07     3.102610e+08   415.318136        20.310309
# min         1.200000e+07     2.992769e+08   142.489871        72.000000
# 25%         9.200000e+07     3.713506e+08   304.796374       102.000000
# 50%         1.450000e+08     5.295307e+08   414.780490       118.000000
# 75%         1.800000e+08     7.665751e+08   641.749457       133.000000
# max         3.306000e+08     2.048134e+09  2559.723617       180.000000
#
#        averagerating
# count     169.000000
# mean        6.966864
# std         0.825323
# min         4.100000
# 25%         6.500000
# 50%         7.000000
# 75%         7.600000
# max         8.600000

# %% [markdown]
# We now have a reletively clean DataFrame that can be used to obtain relevant and reliable insights.

# %% [markdown]
# ## Data Analysis
# > The analysis phase focuses on exploring the relationships in the previously prepared data to determine.
#
# We shall be looking at the relationsips the different features within and the RoI of a film.

# %% [markdown]
# 1. **Runtime:**
#     * The runtime of the film is the length of the film in minutes. We are going to plot a scatter plot to visualize the relationship between the 'runtime_minutes' and 'RoI'.

# %%
fig, ax = plt.subplots(figsize=(20,7))

ax.scatter(top_movies_df['runtime_minutes'], top_movies_df['RoI'], c='orange', alpha=0.5)
ax.set_xlabel('Runtime (minutes)', fontsize=15)
ax.set_ylabel('Return on Investment (%)', fontsize=15)
ax.set_title('Runtime vs Return on Investment', fontsize=20);

# %%
# Evalulate the Pearson correlation coefficient between the 'runtime_minutes' and 'RoI' columns
np.corrcoef(top_movies_df['runtime_minutes'], top_movies_df['RoI'])[0,1]
# Out:
# -0.096733990756916

# %% [markdown]
# From the scatter plot above, we can see that there is no distinct relationship between the runtime and the RoI. Furthermore, looking at the pearson correlation coefficient, we also see that the correlation coefficient is closer to 0. This therefore suggests that the length of a film has not impact on its RoI.

# %% [markdown]
# 2. **Production Budget**
#    * The production budget of the film is the amount of money that the studio invests into the making of the film. We are going to plot a scatter plot to visualize the relationship between the 'production_budget' and 'RoI'.

# %%
fig, ax = plt.subplots(figsize=(20,7))

ax.scatter(top_movies_df['production_budget']*(10**(-6)), top_movies_df['RoI'], c='lightgreen', alpha=0.7)
ax.set_xlabel('Production Budget (Million Dollars)', fontsize=15)
ax.set_ylabel('Return on Investment (%)', fontsize=15)
ax.set_title('Production Budget vs Return on Investment', fontsize=20);

# %%
# Evaluate the Pearson correlation coefficient between the 'production_budget' and 'RoI' columns
np.corrcoef(top_movies_df['production_budget'], top_movies_df['RoI'])[0,1]
# Out:
# -0.6014369562247763

# %% [markdown]
# From the scatter plot above, we see that there is a negative correlation between the production budget and the RoI. However, this relationship is not linear. From 0 to 100 million dollars, the correlation is strongly negative. However, from 100 to 300 million dollars, there is no distict correlation between the return on investment and the budget. Looking at the Pearson correlation coefficient, we see that the correlation coefficient (-0.6) suggests a moderately negative relationship between the return on investment and the production budget.

# %% [markdown]
# 3. **Worldwide Gross**
#     * The worldwide gross of the film is the amount of money that the film made worldwide. We are going to plot a scatter plot to visualize the relationship between the 'worldwide_gross' and 'RoI'.

# %%
# Create a scatter plot to visualize worldwide gross vs RoI
fig, ax = plt.subplots(figsize=(20,7))

ax.scatter(top_movies_df['worldwide_gross']*(10**(-6)), top_movies_df['RoI'], c='orange', alpha=0.5)
ax.set_xlabel('Worldwide Gross (Million Dollars)', fontsize=15)
ax.set_ylabel('Return on Investment (%)', fontsize=15)
ax.set_title('Worldwide Gross vs Return on Investment', fontsize=20);

# %%
# We can also look at the Pearson correlation coefficient between the 'worldwide_gross' and 'RoI' columns
np.corrcoef(top_movies_df['worldwide_gross'], top_movies_df['RoI'])[0,1]
# Out:
# 0.1511294766315754

# %% [markdown]
# From the scatter plot above, there is no distinct relationship between the worldwide gross and the RoI. Looking at the Pearson correlation coefficient, we see that the correlation coefficient (0.15) is closer to 0 therefore suggesting that the worldwide gross of a film has no impact on its RoI.

# %% [markdown]
# 4. **Release Date**
#     * The release time of the film is the time that the film was released. We shall be looking to see if there is a relationship between the release date and the RoI.

# %% [markdown]
# **Month**
# * We are first going to be focusing on the month that the films were released and plot a bar plot to visualize the relationship between the month of release and the average RoI.

# %%
# Create a new column that contains the month that the movies were released
release_time_df = top_movies_df.copy()
release_time_df['release_month'] = release_time_df["release_date"].dt.strftime('%B').astype(str)

release_time_df.head() # Preview the updated 'release_time_df' DataFrame
# Out:
#     movie_id release_date                   movie  production_budget  \
# 0  tt2582846   2014-06-06  The Fault in Our Stars           12000000
# 1  tt3783958   2016-12-09              La La Land           20000000
# 2  tt5140878   2017-08-11     Annabelle: Creation           15000000
# 3  tt1396484   2017-09-08                      It           35000000
# 4  tt6644200   2018-04-06           A Quiet Place           17000000
#
#    worldwide_gross          RoI  runtime_minutes                   genres  \
# 0        307166834  2559.723617            126.0            Drama,Romance
# 1        426351163  2131.755815            128.0       Comedy,Drama,Music
# 2        305384865  2035.899100            109.0  Horror,Mystery,Thriller
# 3        697457969  1992.737054            135.0          Horror,Thriller
# 4        334522294  1967.778200             90.0      Drama,Horror,Sci-Fi
#
#    averagerating release_month
# 0            7.7          June
# 1            8.0      December
# ...

# %%
# Create a plot that shows average return on investment (RoI) by month
fig, ax = plt.subplots(figsize=(13,7))
release_time_df.groupby('release_month')['RoI'].mean().sort_values().plot(kind='bar', figsize=(20,7), color='lightblue')
ax.set_xlabel('Month', fontsize=15)
plt.xticks(rotation=0)
ax.set_ylabel('Average Return on Investment (%)', fontsize=15)
ax.set_title('Average Return on Investment per Month of Release', fontsize=20);

# %% [markdown]
# We see that films that are released in September and October (Fall Season) seem to be having a higher average return on investment than films that are released in the other months. However, we also need to take into account the distribution of the films released per month.

# %%
# Create a plot that shows the number of films released each month
fig, ax = plt.subplots(figsize=(13,7))
release_time_df.groupby('release_month')['movie'].count().sort_values().plot(kind='bar', figsize=(20,7), color='lightgreen')
ax.set_xlabel('Month', fontsize=15)
plt.xticks(rotation=0)
ax.set_ylabel('Number of Films', fontsize=15)
ax.set_title('Distribution Of Films Released per Month', fontsize=20);

# %% [markdown]
# From the 'Number of Films Released per Month' plot above, we can see that the distribution of the number of films released per month is not the most even. This may therefore suggest why months such as September and October which have fewer number of films classified under them are having a higher average return on investment than the others.

# %% [markdown]
# **Season**
# * We are now going to look at the seasons that the films were released and plot a bar plot to visualize the average RoI per season.

# %%
# Create a dictionary that maps months to their season
seasons = {'January':'Winter',
           'February':'Winter',
           'March':'Spring',
           'April':'Spring',
           'May':'Spring',
           'June':'Summer',
           'July':'Summer',
           'August':'Summer',
           'September':'Fall',
           'October':'Fall',
           'November':'Fall',
           'December':'Winter'}

# Create a new column that contains the season that the movie was released in
release_time_df['release_season'] = release_time_df['release_month'].map(seasons)

release_time_df.head() # Preview the updated 'release_time_df' DataFrame
# Out:
#     movie_id release_date                   movie  production_budget  \
# 0  tt2582846   2014-06-06  The Fault in Our Stars           12000000
# 1  tt3783958   2016-12-09              La La Land           20000000
# 2  tt5140878   2017-08-11     Annabelle: Creation           15000000
# 3  tt1396484   2017-09-08                      It           35000000
# 4  tt6644200   2018-04-06           A Quiet Place           17000000
#
#    worldwide_gross          RoI  runtime_minutes                   genres  \
# 0        307166834  2559.723617            126.0            Drama,Romance
# 1        426351163  2131.755815            128.0       Comedy,Drama,Music
# 2        305384865  2035.899100            109.0  Horror,Mystery,Thriller
# 3        697457969  1992.737054            135.0          Horror,Thriller
# 4        334522294  1967.778200             90.0      Drama,Horror,Sci-Fi
#
#    averagerating release_month release_season
# 0            7.7          June         Summer
# ...

# %%
# Create a plot that shows average return on investment (RoI) by season
fig, ax = plt.subplots(figsize=(20,7))

release_time_df.groupby('release_season')['RoI'].mean().sort_values().plot(kind='bar', color='orange')
ax.set_xlabel('Season', fontsize=15)
plt.xticks(rotation=0)
ax.set_ylabel('Average Return on Investment (%)', fontsize=15)
ax.set_title('Average Return on Investment per Season of Release', fontsize=20);

# %% [markdown]
# According to the bar plot above, we see that the average return on investment for films released in the Fall is the highest. It is closely followed by Winter, then Summer, and lastly Spring. However, before making any conclusions, we need to take into account the distribution of the films released per season.

# %%
# Create a plot that shows the number of films released each season
fig, ax = plt.subplots(figsize=(20,7))

release_time_df.groupby('release_season')['movie'].count().sort_values().plot(kind='bar', color='lightgreen')
ax.set_xlabel('Season', fontsize=15)
plt.xticks(rotation=0)
ax.set_ylabel('Number of Films', fontsize=15)
ax.set_title('Distribution Of Films Released per Season', fontsize=20);

# %% [markdown]
# Based on the 'Number of Films Released per Season' plot above, we can see that the distribution of the number of films released per season is fairly even. We see that despite Summer having the most number of films released, the average return on investment is not the lowest, in fact, it is comparable to the average return on investment for the the top (Fall) season. This suggests that Summer could be best season to release a film.

# %% [markdown]
# 5. **Genre**
#     * The genre of the film is the category within which the film is classified. We are going to plot a barchart to visualize the relationship between the 'genre' and average 'RoI' for that genre. However, before we can plot, the genre column needs to normalized.

# %%
# Assign the top_movies_df DataFrame to a new variable called 'genre_analysis_df'. It shall be used for genre analysis
genre_analysis_df = top_movies_df.copy()
genre_analysis_df['genres'] = genre_analysis_df.genres.apply(lambda x: x.split(','))

genre_analysis_df = genre_analysis_df.explode('genres') # Normalize the 'genres' column by exploding the list of genres

genre_analysis_df.head() # Preview the first few records of the 'genre_analysis_df' DataFrame
# Out:
#     movie_id release_date                   movie  production_budget  \
# 0  tt2582846   2014-06-06  The Fault in Our Stars           12000000
# 0  tt2582846   2014-06-06  The Fault in Our Stars           12000000
# 1  tt3783958   2016-12-09              La La Land           20000000
# 1  tt3783958   2016-12-09              La La Land           20000000
# 1  tt3783958   2016-12-09              La La Land           20000000
#
#    worldwide_gross          RoI  runtime_minutes   genres  averagerating
# 0        307166834  2559.723617            126.0    Drama            7.7
# 0        307166834  2559.723617            126.0  Romance            7.7
# 1        426351163  2131.755815            128.0   Comedy            8.0
# 1        426351163  2131.755815            128.0    Drama            8.0
# 1        426351163  2131.755815            128.0    Music            8.0

# %% [markdown]
# The 'genres' columns have been normalised successfully. Now we need to identify the different genres within the 'genres' column.

# %%
genre_analysis_df.genres.unique() # Identify the unique genres in the 'genre_analysis_df' DataFrame
# Out:
# array(['Drama', 'Romance', 'Comedy', 'Music', 'Horror', 'Mystery',
#        'Thriller', 'Sci-Fi', 'Biography', 'Adventure', 'Animation',
#        'Family', 'Action', 'Fantasy', 'Musical', 'Crime', 'Western',
#        'History', 'War', 'Documentary'], dtype=object)

# %% [markdown]
#  There is both a 'Music' and 'Musical' genre which is most probably an error. Therefore, we need to combine the two genres into one that we shall call 'Music'.

# %%
# Identify the records that belong to the 'Musical' genre an convert them to 'Music' genre
genre_analysis_df.loc[genre_analysis_df['genres'] == 'Musical', 'genres'] = 'Music'

genre_analysis_df.genres.unique() # Check if the unique genres have been updated
# Out:
# array(['Drama', 'Romance', 'Comedy', 'Music', 'Horror', 'Mystery',
#        'Thriller', 'Sci-Fi', 'Biography', 'Adventure', 'Animation',
#        'Family', 'Action', 'Fantasy', 'Crime', 'Western', 'History',
#        'War', 'Documentary'], dtype=object)

# %%
# Create a plot that shows average return on investment (RoI) by genre
fig, ax = plt.subplots( figsize=(20,7))

genre_analysis_df.groupby('genres')['RoI'].mean().sort_values().plot(kind='bar',color='yellow')
ax.set_xlabel('Genre', fontsize=15)
plt.xticks(rotation=0)
ax.set_ylabel('Average Return on Investment (%)', fontsize=15)
ax.set_title('Average Return on Investment per Genre', fontsize=20);

# %% [markdown]
# We see that 'Music' and 'Horror' genres have a higher average return on investment than other genres. However, before any conclusion can be made, we need to first understand the number of films released in each genre and gauge the distribution per genre.

# %%
# Create a plot that counts the number of movies by genre
fig, ax = plt.subplots(figsize=(13,7))

genre_analysis_df.groupby('genres')['movie'].count().sort_values().plot(kind='bar', figsize=(20,7), color='orange')
ax.set_xlabel('Genre', fontsize=15)
plt.xticks(rotation=0)
ax.set_ylabel('Number of Films', fontsize=15)
ax.set_title('Distribution Of Films per Genre', fontsize=20);

# %% [markdown]
#  From the plot above, we can see that the distribution of the genre of films in the dataset is not evenly distributed. Therefore, we need to take this into account that the reason that the 'Horror' and 'Music' genre have a higher average return on investment is because there are fewer films classified under them. It is however important to note that of the Top 200 Highest Grossing Films that were originally selected, majority of were Adventure and Action. This suggests that Adventure and Action films averagely make the most money.

# %% [markdown]
# 6. **Directors**
#    * We are going to plot a barchart to visualize the relationship between directors and average RoI for the films. We first need to create a new DataFrame that contains the movies and their director information.

# %%
# Create a copy of the 'top_movies_df' DataFrame to a new variable called 'director_analysis_df'
director_analysis_df = top_movies_df.copy()

# Join the directors_df DataFrame to the top_movies_df DataFrame and assign it to a new DataFrame called 'director_analysis_df'
director_analysis_df = director_analysis_df.join(directors_df.set_index('movie_id'), on='movie_id', how='left')

# Join the persons_df DataFrame to the director_analysis_df DataFrame so that we can identify their names and know whether they are still alive or not
director_analysis_df = director_analysis_df.join(persons_df.set_index('person_id'), on='person_id', how='inner')
director_analysis_df # Preview the updated 'director_analysis_df' DataFrame
# Out:
#       movie_id release_date                           movie  \
# 0    tt2582846   2014-06-06          The Fault in Our Stars
# 1    tt3783958   2016-12-09                      La La Land
# 2    tt5140878   2017-08-11             Annabelle: Creation
# 74   tt0448115   2019-04-05                         Shazam!
# 3    tt1396484   2017-09-08                              It
# ..         ...          ...                             ...
# 164  tt2660888   2016-07-22                Star Trek Beyond
# 165  tt1979388   2015-11-25               The Good Dinosaur
# 166  tt3741700   2019-05-31  Godzilla: King of the Monsters
# 167  tt3778644   2018-05-25         Solo: A Star Wars Story
# 168  tt1440129   2012-05-18                      Battleship
#
#      production_budget  worldwide_gross          RoI  runtime_minutes  \
# 0             12000000        307166834  2559.723617            126.0
# 1             20000000        426351163  2131.755815            128.0
# ...

# %% [markdown]
# Next we need to check if any of the directors are still alive. If that is not the case, we will need to drop their records from the DataFrame.

# %%
# Check if any records have directors that have passed on. If so, drop the records from the 'director_analysis_df' DataFrame
director_analysis_df[director_analysis_df['death_year'].notna()]
# Out:
# Empty DataFrame
# Columns: [movie_id, release_date, movie, production_budget, worldwide_gross, RoI, runtime_minutes, genres, averagerating, person_id, primary_name, birth_year, death_year, primary_profession]
# Index: []

# %% [markdown]
# As we are looking for directors with a proven track record, we need to identify directors that have more than one film in our DataFrame. Thereafter, we will be plot a barchart to visualize the relationship between directors and average RoI for their films.

# %%
# Directors with more than one film will give the 'person_id' column duplicates. Therefore, we need to identify the duplicate person_id values
director_ids = director_analysis_df[director_analysis_df.duplicated(subset='person_id')]['person_id'].unique()

# Update the 'director_analysis_df' DataFrame to only include directors with multiple films
director_analysis_df = director_analysis_df[director_analysis_df['person_id'].isin(director_ids)]
director_analysis_df # Preview the updated 'director_analysis_df' DataFrame
# Out:
#       movie_id release_date                               movie  \
# 2    tt5140878   2017-08-11                 Annabelle: Creation
# 74   tt0448115   2019-04-05                             Shazam!
# 5    tt1727824   2018-11-02                   Bohemian Rhapsody
# 106  tt1877832   2014-05-23          X-Men: Days of Future Past
# 126  tt3385516   2016-05-27                   X-Men: Apocalypse
# ..         ...          ...                                 ...
# 112  tt1872181   2014-05-02            The Amazing Spider-Man 2
# 115  tt0948470   2012-07-03              The Amazing Spider-Man
# 113  tt2975590   2016-03-25  Batman v Superman: Dawn of Justice
# 134  tt0770828   2013-06-14                        Man of Steel
# 155  tt0974015   2017-11-17                      Justice League
#
#      production_budget  worldwide_gross          RoI  runtime_minutes  \
# 2             15000000        305384865  2035.899100            109.0
# ...

# %%
# Plot a bar chart that shows the average film (RoI) per director for the top 20 directors
fig, ax = plt.subplots(figsize=(20,7))

director_analysis_df.groupby('primary_name')['RoI'].mean().sort_values(ascending=False)[:20].plot(kind='barh', color='lightblue')
ax.set_ylabel('Director', fontsize=15)
ax.set_xlabel('Average Return on Investment (%)', fontsize=15)
ax.set_title('Average Return on Investment per Director', fontsize=20);

# %% [markdown]
# We see that the Top 5 directors with a highest average return on investment are: Kyle Balda, Pierre Coffin, Chris Rennaud, David F. Sandberg, and James Wan.

# %% [markdown]
# 7. **Actors**
#     * We are going to plot a barchart to visualize the relationship between actors and average RoI for the films. We first need to create a new DataFrame that contains the movies and their actor information.

# %%
# Create a copy of the 'top_movies_df' DataFrame to a new variable called 'writer_analysis_df'
writer_analysis_df = top_movies_df.copy()

# Join the top_movies_df DataFrame to the writer_analysis_df DataFrame
writer_analysis_df = writer_analysis_df.join(writers_df.set_index('movie_id'), on='movie_id', how='left')

# Join the persons_df DataFrame to the writer_analysis_df DataFrame so that we can identify their names
writer_analysis_df = writer_analysis_df.join(persons_df.set_index('person_id'), on='person_id', how='inner')
writer_analysis_df # Preview the updated 'writer_analysis_df' DataFrame
# Out:
#       movie_id release_date                           movie  \
# 0    tt2582846   2014-06-06          The Fault in Our Stars
# 0    tt2582846   2014-06-06          The Fault in Our Stars
# 0    tt2582846   2014-06-06          The Fault in Our Stars
# 1    tt3783958   2016-12-09                      La La Land
# 2    tt5140878   2017-08-11             Annabelle: Creation
# ..         ...          ...                             ...
# 165  tt1979388   2015-11-25               The Good Dinosaur
# 166  tt3741700   2019-05-31  Godzilla: King of the Monsters
# 167  tt3778644   2018-05-25         Solo: A Star Wars Story
# 167  tt3778644   2018-05-25         Solo: A Star Wars Story
# 167  tt3778644   2018-05-25         Solo: A Star Wars Story
#
#      production_budget  worldwide_gross          RoI  runtime_minutes  \
# 0             12000000        307166834  2559.723617            126.0
# 0             12000000        307166834  2559.723617            126.0
# ...

# %% [markdown]
# As we are once again looking for writers with a proven track record, we need to identify directors that have more than one film in our DataFrame. Thereafter, we will be plot a barchart to visualize the relationship between these writers and the average RoI for their films.

# %%
# Writers with more than one film will give the 'person_id' column duplicates. Therefore, we need to identify the duplicate person_id values
writer_ids = writer_analysis_df[writer_analysis_df.duplicated(subset='person_id')]['person_id'].unique()

# Update the 'writer_analysis_df' DataFrame to only include writers with multiple films
writer_analysis_df = writer_analysis_df[writer_analysis_df['person_id'].isin(writer_ids)]
writer_analysis_df # Preview the updated 'director_analysis_df' DataFrame
# Out:
#       movie_id release_date                      movie  production_budget  \
# 2    tt5140878   2017-08-11        Annabelle: Creation           15000000
# 3    tt1396484   2017-09-08                         It           35000000
# 7    tt2293640   2015-07-10                    Minions           74000000
# 7    tt2293640   2015-07-10                    Minions           74000000
# 14   tt2709768   2016-07-08    The Secret Life of Pets           75000000
# ..         ...          ...                        ...                ...
# 164  tt2660888   2016-07-22           Star Trek Beyond          185000000
# 148  tt1623205   2013-03-08  Oz the Great and Powerful          200000000
# 157  tt1446192   2012-11-21      Rise of the Guardians          145000000
# 158  tt2345759   2017-06-09                  The Mummy          195000000
# 159  tt1631867   2014-06-06           Edge of Tomorrow          178000000
#
#      worldwide_gross          RoI  runtime_minutes  \
# ...

# %%
# Plot a bar chart that shows the average film (RoI) per writer for the top 20 writers
fig, ax = plt.subplots(figsize=(20,7))

writer_analysis_df.groupby('primary_name')['RoI'].mean().sort_values(ascending=False)[:20].plot(kind='barh', color='lightgreen')
ax.set_ylabel('Writer', fontsize=15)
ax.set_xlabel('Average Return on Investment (%)', fontsize=15)
ax.set_title('Average Return on Investment per Writer', fontsize=20);

# %% [markdown]
# We see that Gary Dauberman has the highest average RoI amongst the writers with an average RoI that's nearly 50% better than the second highest writer, Brian Lynch.

# %% [markdown]
# 8. **Rating**
#    * The rating of the film is the rank on a scale of 0-10 that the film was given by the people. We are going to plot a scatter plot to visualize the relationship between the 'rating' and 'RoI'. From this we want to see what people think of these top performing films and whether being a top performing film means that it is a good film.

# %%
# Plot a scatter plot that shows the relationship between RoI and rating 
fig, ax = plt.subplots(figsize=(20,7))

ax.scatter(top_movies_df['averagerating'], top_movies_df['RoI'], alpha=0.5, color='orange')
ax.set_xlabel('Rating', fontsize=15)
ax.set_ylabel('Return on Investment (%)', fontsize=15)
ax.set_title('Average Rating vs Return on Investment', fontsize=20);

# %%
# Evaluate the Pearson correlation coefficient between the 'averagerating' and 'RoI' columns
np.corrcoef(top_movies_df['averagerating'], top_movies_df['RoI'])[0,1]
# Out:
# 0.1519738142877462

# %% [markdown]
# Based on the scatter plot, it is difficult to see any distinct relationship between the rating and the RoI. However, looking at the Pearson correlation coefficient (0.15), we see that it is closer to 0 therefore confirming that there is indeed no relationship between the rating of a film and the RoI.
